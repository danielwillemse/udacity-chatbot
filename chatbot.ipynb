# %%
from torch import cuda

device = 'cuda' if cuda.is_available() else 'cpu'
cuda.empty_cache()
print(device)
# Out:
# cuda

# %%
import os, glob
import pandas as pd
import tiktoken

tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
import openai
openai.api_base = "https://openai.vocareum.com/v1"
openai.api_key = "YOU API KEY"

# %%
COMPLETION_MODEL="gpt-3.5-turbo-instruct"
COMPLETION_TOKEN_LIMIT=3900
EMBEDDING_MODEL="text-embedding-ada-002"
EMBEDDING_TOKEN_LIMIT=8000

# %%
q1 = "Can you list all creature cards of type Dragon that were printed in 2024?"
q2 = "It's 2025. What is the name of the last legendary sliver that was printed?"

# %%
def get_completion(question):
    prompt = """
Question: {question}
Answer:
""".format(question=question)
    answer = openai.Completion.create(
        model=COMPLETION_MODEL,
        prompt=question,
        max_tokens=150
    )["choices"][0]["text"].strip()

    completion = prompt + answer + '\r\n'
    print(completion)
    return completion

# %%
c1 = get_completion(q1)
c2 = get_completion(q2)
# Out:
# Question: Can you list all creature cards of type Dragon that were printed in 2024?
# Answer:
# As a AI, I don't have the data regarding future cards. Hence, I cannot provide a list of creature cards of type Dragon that were printed in 2024.
#
#
# Question: It's 2025. What is the name of the last legendary sliver that was printed?
# Answer:
# Unfortunately, as a language model AI, I do not have access to information beyond the current year. I am unable to answer your question. Apologies for the inconvenience.

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv("data/cards.csv")

def count_tokens(text):
    return len(tokenizer.encode(text))

df["token_count"] = df["text"].map(count_tokens)
df.head()
# Out:
#                                                 text release_date set_code  \
# 0  \nName: Plague Rats\nColors: B\nManacost: {2}{...   1993-08-05      LEA
# 1  \nName: Shivan Dragon\nColors: R\nManacost: {4...   1993-08-05      LEA
# 2  \nName: Stone Giant\nColors: R\nManacost: {2}{...   1993-08-05      LEA
# 3  \nName: Two-Headed Giant of Foriys\nColors: R\...   1993-08-05      LEA
# 4  \nName: Uthden Troll\nColors: R\nManacost: {2}...   1993-08-05      LEA
#
#                       card_id  token_count
# 0                 Plague Rats           74
# 1               Shivan Dragon           67
# 2                 Stone Giant           83
# 3  Two-Headed Giant of Foriys           74
# 4                Uthden Troll           59

# %%
df.describe()
# Out:
#         token_count
# count  16807.000000
# mean      91.294044
# std       22.885193
# min       45.000000
# 25%       74.000000
# 50%       88.000000
# 75%      107.000000
# max      217.000000

# %%
batch_size = 1000
embeddings = []

for i in range(0, len(df), batch_size):
    # Send text data to OpenAI model to get embeddings
    batch = df.iloc[i:i+batch_size]
    print(f"Batch: {i}")

    response = openai.Embedding.create(
        input=batch["text"].tolist(),
        engine=EMBEDDING_MODEL
    )
    
    # Add embeddings to list
    embeddings.extend([data["embedding"] for data in response["data"]])

# Add embeddings list to dataframe
df["embeddings"] = embeddings
df
# Out:
# Batch: 0
# Batch: 1000
# Batch: 2000
# Batch: 3000
# Batch: 4000
# Batch: 5000
# Batch: 6000
# Batch: 7000
# Batch: 8000
# Batch: 9000
# Batch: 10000
# Batch: 11000
# Batch: 12000
# Batch: 13000
# Batch: 14000
# Batch: 15000
# Batch: 16000
#                                                     text release_date  \
# 0      \nName: Plague Rats\nColors: B\nManacost: {2}{...   1993-08-05
# 1      \nName: Shivan Dragon\nColors: R\nManacost: {4...   1993-08-05
# 2      \nName: Stone Giant\nColors: R\nManacost: {2}{...   1993-08-05
# 3      \nName: Two-Headed Giant of Foriys\nColors: R\...   1993-08-05
# 4      \nName: Uthden Troll\nColors: R\nManacost: {2}...   1993-08-05
# ...                                                  ...          ...
# 16802  \nName: Evereth, Viceroy of Plunder\nColors: B...   2024-11-15
# 16803  \nName: Aphelia, Viper Whisperer\nColors: B\nM...   2024-11-15
# 16804  \nName: Taeko, the Patient Avalanche\nColors: ...   2024-11-15
# 16805  \nName: Daretti, Rocketeer Engineer\nColors: R...   2025-02-14
# 16806  \nName: Brightglass Gearhulk\nColors: G, W\nMa...   2025-02-14
#
#       set_code                       card_id  token_count  \
# 0          LEA                   Plague Rats           74
# 1          LEA                 Shivan Dragon           67
# 2          LEA                   Stone Giant           83
# 3          LEA    Two-Headed Giant of Foriys           74
# 4          LEA                  Uthden Troll           59
# ...        ...                           ...          ...
# 16802      J25   Evereth, Viceroy of Plunder          140
# 16803      J25      Aphelia, Viper Whisperer          135
# 16804      J25  Taeko, the Patient Avalanche          119
# 16805      DFT   Daretti, Rocketeer Engineer          105
# 16806      DFT          Brightglass Gearhulk          107
#
#                                               embeddings
# 0      [0.009661226533353329, -0.012912601232528687, ...
# 1      [0.011478732340037823, -0.03415033966302872, -...
# 2      [0.017620408907532692, -0.03125821426510811, -...
# 3      [0.00279824435710907, -0.011686686426401138, -...
# 4      [0.006812881212681532, -0.039526745676994324, ...
# ...                                                  ...
# 16802  [-0.01681125909090042, -0.03981684893369675, 0...
# 16803  [-0.01605450175702572, 0.002617432503029704, -...
# 16804  [0.0005341354408301413, -0.014380116946995258,...
# 16805  [-0.0015830239281058311, -0.022208718582987785...
# 16806  [-0.009808497503399849, -0.01592959091067314, ...
#
# [16807 rows x 6 columns]

# %%
df.to_csv("data/embeddings.csv", index=False)

# %%
import datetime
df["release_date"] = df["release_date"].map(pd.to_datetime)
df_s = df[df["release_date"] > datetime.datetime(2021, 1, 1)]
df_s.to_csv("data/embeddings_new_cards.csv", index=False)
df_s.head()
# Out:
#                                                     text release_date  \
# 12084  \nName: Surtland Elementalist\nColors: U\nMana...   2021-02-05
# 12085  \nName: Lathril, Blade of the Elves\nColors: B...   2021-02-05
# 12086  \nName: Cleaving Reaper\nColors: B\nManacost: ...   2021-02-05
# 12087  \nName: Surtland Flinger\nColors: R\nManacost:...   2021-02-05
# 12088  \nName: Canopy Tactician\nColors: G\nManacost:...   2021-02-05
#
#       set_code                      card_id  token_count  \
# 12084      KHM        Surtland Elementalist          100
# 12085     PKHM  Lathril, Blade of the Elves          124
# 12086      KHM              Cleaving Reaper           94
# 12087      KHM             Surtland Flinger          111
# 12088      KHM             Canopy Tactician           71
#
#                                               embeddings
# 12084  [0.006645162124186754, -0.0017845366382971406,...
# 12085  [-0.012109244242310524, -0.018400194123387337,...
# 12086  [-0.007777650840580463, -0.014852461405098438,...
# 12087  [0.0076932101510465145, -0.015223887749016285,...
# 12088  [-0.006393569055944681, -0.03395732492208481, ...

# %%
from ast import literal_eval
df_s = pd.read_csv("data/embeddings_new_cards.csv")
df_s["embeddings"] = df_s["embeddings"].apply(literal_eval)
df_s.head()
# Out:
#                                                 text release_date set_code  \
# 0  \nName: Surtland Elementalist\nColors: U\nMana...   2021-02-05      KHM
# 1  \nName: Lathril, Blade of the Elves\nColors: B...   2021-02-05     PKHM
# 2  \nName: Cleaving Reaper\nColors: B\nManacost: ...   2021-02-05      KHM
# 3  \nName: Surtland Flinger\nColors: R\nManacost:...   2021-02-05      KHM
# 4  \nName: Canopy Tactician\nColors: G\nManacost:...   2021-02-05      KHM
#
#                        card_id  token_count  \
# 0        Surtland Elementalist          100
# 1  Lathril, Blade of the Elves          124
# 2              Cleaving Reaper           94
# 3             Surtland Flinger          111
# 4             Canopy Tactician           71
#
#                                           embeddings
# 0  [0.006645162124186754, -0.0017845366382971406,...
# 1  [-0.012109244242310524, -0.018400194123387337,...
# 2  [-0.007777650840580463, -0.014852461405098438,...
# 3  [0.0076932101510465145, -0.015223887749016285,...
# 4  [-0.006393569055944681, -0.03395732492208481, ...

# %%
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL)
    
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embeddings,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )
    
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
p1_distances = get_rows_sorted_by_relevance(q1, df)
p1_distances.head()
# Out:
#                                                     text release_date  \
# 3612   \nName: Timeless Dragon\nColors: W\nManacost: ...   2002-06-24
# 13291  \nName: Draconic Muralists\nColors: G\nManacos...   2022-06-10
# 2870   \nName: Artificer's Dragon\nColors: \nManacost...   2002-06-24
# 2966   \nName: Dragonlord Dromoka\nColors: G, W\nMana...   2002-06-24
# 13272  \nName: Chardalyn Dragon\nColors: \nManacost: ...   2022-06-10
#
#       set_code             card_id  token_count  \
# 3612       PRM     Timeless Dragon          147
# 13291      CLB  Draconic Muralists           89
# 2870       PRM  Artificer's Dragon          125
# 2966       PRM  Dragonlord Dromoka           80
# 13272      CLB    Chardalyn Dragon           56
#
#                                               embeddings  distances
# 3612   [-0.0024310285225510597, -0.023831838741898537...   0.178517
# 13291  [-0.010951120406389236, -0.009599453769624233,...   0.181099
# 2870   [0.014701064676046371, -0.02380487509071827, -...   0.182095
# 2966   [-0.0031070502009242773, -0.016883350908756256...   0.182899
# 13272  [0.004365582950413227, -0.030372627079486847, ...   0.183069

# %%
p2_distances = get_rows_sorted_by_relevance(q2, df)
p2_distances.head()
# Out:
#                                                    text release_date set_code  \
# 5727  \nName: Sliver Legion\nColors: B, G, R, U, W\n...   2007-05-04      FUT
# 5725  \nName: Sliversmith\nColors: \nManacost: {2}\n...   2007-05-04      FUT
# 8381  \nName: Sliver Hivelord\nColors: B, G, R, U, W...   2014-07-18      M15
# 1301  \nName: Sliver Queen\nColors: B, G, R, U, W\nM...   1998-03-02      STH
# 1247  \nName: Metallic Sliver\nColors: \nManacost: {...   1997-10-14      TMP
#
#               card_id  token_count  \
# 5727    Sliver Legion           81
# 5725      Sliversmith           76
# 8381  Sliver Hivelord           91
# 1301     Sliver Queen           79
# 1247  Metallic Sliver           46
#
#                                              embeddings  distances
# 5727  [0.005937935318797827, -0.010013777762651443, ...   0.178894
# 5725  [-0.008756960742175579, -0.005619939882308245,...   0.186844
# 8381  [0.0015946932835504413, -0.0015330156311392784...   0.190061
# 1301  [0.0011914916103705764, -0.007616425398737192,...   0.190189
# 1247  [-0.00648983009159565, -0.01784372888505459, -...   0.191153

# %%
PROMPT_TEMPLATE = """
The year is 2025. You are given <context> that contains card information from 2021 until 2025.
Answer the following <question> based on the given context that contains information of newly printed cards.
Answer "I don't know" if an answer cannot be found.

Context: 

{context}

---

Question: {question}
Answer:"""

def create_prompt(question, df):
    current_token_count = len(tokenizer.encode(PROMPT_TEMPLATE)) + \
                            len(tokenizer.encode(question))

    files_added = []
    context = []
    relevant_rows = get_rows_sorted_by_relevance(question, df)
    for idx, row in relevant_rows.iterrows():
        if (current_token_count + row["token_count"] <= COMPLETION_TOKEN_LIMIT):
            current_token_count += row["token_count"]
            context.append(row["text"])
        else:
            break

    return PROMPT_TEMPLATE.format(context="\n###\n".join(context), question=question)

test_prompt = create_prompt(q2, df)
print(len(tokenizer.encode(test_prompt)))
# Out:
# 3887

# %%
print(test_prompt)
# Out:
# The year is 2025. You are given <context> that contains card information from 2021 until 2025.
# Answer the following <question> based on the given context that contains information of newly printed cards.
# Answer "I don't know" if an answer cannot be found.
#
# Context:
#
#
# Name: Sliver Legion
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver
# Text: All Sliver creatures get +1/+1 for each other Sliver on the battlefield.
# Set: Future Sight (FUT)
# Release date: 2007-05-04
#
# ###
#
# Name: Sliversmith
# Colors:
# Manacost: {2}
# Type: Artifact Creature — Spellshaper
# Text: {1}, {T}, Discard a card: Create a 1/1 colorless Sliver artifact creature token named Metallic Sliver.
# Set: Future Sight (FUT)
# Release date: 2007-05-04
#
# ###
#
# Name: Sliver Hivelord
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver
# Text: Sliver creatures you control have indestructible. (Damage and effects that say "destroy" don't destroy them.)
# Set: Magic 2015 (M15)
# Release date: 2014-07-18
#
# ###
#
# Name: Sliver Queen
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver
# Text: {2}: Create a 1/1 colorless Sliver creature token.
# Set: Stronghold (STH)
# Release date: 1998-03-02
#
# ###
#
# Name: Metallic Sliver
# Colors:
# Manacost: {1}
# Type: Artifact Creature — Sliver
# Text: -
# Set: Tempest (TMP)
# Release date: 1997-10-14
#
# ###
#
# Name: Battle Sliver
# Colors: R
# Manacost: {4}{R}
# Type: Creature — Sliver
# Text: Sliver creatures you control get +2/+0.
# Set: Magic 2014 (M14)
# Release date: 2013-07-19
#
# ###
#
# Name: Sliver Construct
# Colors:
# Manacost: {3}
# Type: Artifact Creature — Sliver Construct
# Text: -
# Set: Magic 2014 (M14)
# Release date: 2013-07-19
#
# ###
#
# Name: The First Sliver
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver
# Text: Cascade (When you cast this spell, exile cards from the top of your library until you exile a nonland card that costs less. You may cast it without paying its mana cost. Put the exiled cards on the bottom in a random order.)
# Sliver spells you cast have cascade.
# Set: Magic Online Promos (PRM)
# Release date: 2002-06-24
#
# ###
#
# Name: Constricting Sliver
# Colors: W
# Manacost: {5}{W}
# Type: Creature — Sliver
# Text: Sliver creatures you control have "When this creature enters, you may exile target creature an opponent controls until this creature leaves the battlefield."
# Set: Magic 2015 (M15)
# Release date: 2014-07-18
#
# ###
#
# Name: Sliver Overlord
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver Mutant
# Text: {3}: Search your library for a Sliver card, reveal that card, put it into your hand, then shuffle.
# {3}: Gain control of target Sliver. (This effect lasts indefinitely.)
# Set: Scourge (SCG)
# Release date: 2003-05-26
#
# ###
#
# Name: Spectral Sliver
# Colors: B
# Manacost: {2}{B}
# Type: Creature — Sliver Spirit
# Text: All Sliver creatures have "{2}: This creature gets +1/+1 until end of turn."
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Sliver Gravemother
# Colors: B, G, R, U, W
# Manacost: {W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver
# Text: The "legend rule" doesn't apply to Slivers you control.
# Each Sliver creature card in your graveyard has encore {X}, where X is its mana value.
# Encore {5} ({5}, Exile this card from your graveyard: For each opponent, create a token copy that attacks that opponent this turn if able. They gain haste. Sacrifice them at the beginning of the next end step. Activate only as a sorcery.)
# Set: Commander Masters (CMM)
# Release date: 2023-08-04
#
# ###
#
# Name: Magma Sliver
# Colors: R
# Manacost: {3}{R}
# Type: Creature — Sliver
# Text: All Slivers have "{T}: Target Sliver creature gets +X/+0 until end of turn, where X is the number of Slivers on the battlefield."
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Dementia Sliver
# Colors: B, U
# Manacost: {3}{U}{B}
# Type: Creature — Sliver
# Text: All Slivers have "{T}: Choose a card name. Target opponent reveals a card at random from their hand. If that card has the chosen name, that player discards it. Activate only during your turn."
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: The Fifth Alias
# Colors: R, U, W
# Manacost: {2}{U}{R}{W}
# Type: Legendary Creature — Shapeshifter
# Text: Before the game begins, if The Fifth Alias is your commander or in your deck, secretly make a list of five nonland cards in your deck. (Don't forget to do this!)
# As you draw a card on your list, you may reveal it, show it was on the list, and exclaim its name. If you do, cast it without paying its mana cost.
# Set: Unknown Event (DA1)
# Release date: 2023-02-15
#
# ###
#
# Name: Enduring Sliver
# Colors: W
# Manacost: {1}{W}
# Type: Creature — Sliver
# Text: Outlast {2} ({2}, {T}: Put a +1/+1 counter on this creature. Outlast only as a sorcery.)
# Other Sliver creatures you control have outlast {2}.
# Set: Modern Horizons (MH1)
# Release date: 2019-06-14
#
# ###
#
# Name: Might Sliver
# Colors: G
# Manacost: {4}{G}
# Type: Creature — Sliver
# Text: All Sliver creatures get +2/+2.
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Virulent Sliver
# Colors: G
# Manacost: {G}
# Type: Creature — Sliver
# Text: All Sliver creatures have poisonous 1. (Whenever a Sliver deals combat damage to a player, that player gets a poison counter. A player with ten or more poison counters loses the game.)
# Set: Future Sight (FUT)
# Release date: 2007-05-04
#
# ###
#
# Name: Belligerent Sliver
# Colors: R
# Manacost: {2}{R}
# Type: Creature — Sliver
# Text: Sliver creatures you control have menace. (They can't be blocked except by two or more creatures.)
# Set: Magic 2015 (M15)
# Release date: 2014-07-18
#
# ###
#
# Name: Blade Sliver
# Colors: R
# Manacost: {2}{R}
# Type: Creature — Sliver
# Text: All Sliver creatures get +1/+0.
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Venser's Sliver
# Colors:
# Manacost: {5}
# Type: Artifact Creature — Sliver
# Text: -
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Mindlash Sliver
# Colors: B
# Manacost: {B}
# Type: Creature — Sliver
# Text: All Slivers have "{1}, Sacrifice this permanent: Each player discards a card."
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Plated Sliver
# Colors: W
# Manacost: {W}
# Type: Creature — Sliver
# Text: All Sliver creatures get +0/+1.
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Sliver of Hope
# Colors: W
# Manacost: {3}{W}
# Type: Creature — Sliver
# Text: Slivers you control have hope. (Prevent all damage that would be dealt to attacking creatures with hope.)
# Set: Mystery Booster 2 (MB2)
# Release date: 2024-08-02
#
# ###
#
# Name: Megantic Sliver
# Colors: G
# Manacost: {5}{G}
# Type: Creature — Sliver
# Text: Sliver creatures you control get +3/+3.
# Set: Magic Online Promos (PRM)
# Release date: 2002-06-24
#
# ###
#
# Name: Quick Sliver
# Colors: G
# Manacost: {1}{G}
# Type: Creature — Sliver
# Text: Flash
# Any player may cast Sliver spells as though they had flash.
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Homing Sliver
# Colors: R
# Manacost: {2}{R}
# Type: Creature — Sliver
# Text: Each Sliver card in each player's hand has slivercycling {3}.
# Slivercycling {3} ({3}, Discard this card: Search your library for a Sliver card, reveal it, put it into your hand, then shuffle.)
# Set: Future Sight (FUT)
# Release date: 2007-05-04
#
# ###
#
# Name: Fury Sliver
# Colors: R
# Manacost: {5}{R}
# Type: Creature — Sliver
# Text: All Sliver creatures have double strike.
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Capricious Sliver
# Colors: R
# Manacost: {3}{R}
# Type: Creature — Sliver
# Text: Sliver creatures you control have "Whenever this creature deals combat damage to a player, exile the top card of your library. You may play that card this turn."
# Set: Commander Masters (CMM)
# Release date: 2023-08-04
#
# ###
#
# Name: Spitting Sliver
# Colors: B
# Manacost: {4}{B}
# Type: Creature — Sliver
# Text: All Sliver creatures have first strike.
# Set: Planar Chaos (PLC)
# Release date: 2007-02-02
#
# ###
#
# Name: Shifting Sliver
# Colors: U
# Manacost: {3}{U}
# Type: Creature — Sliver
# Text: Slivers can't be blocked except by Slivers.
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Ghostflame Sliver
# Colors: B, R
# Manacost: {B}{R}
# Type: Creature — Sliver
# Text: All Slivers are colorless.
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Frenzy Sliver
# Colors: B
# Manacost: {1}{B}
# Type: Creature — Sliver
# Text: All Sliver creatures have frenzy 1. (Whenever a Sliver attacks and isn't blocked, it gets +1/+0 until end of turn.)
# Set: Future Sight (FUT)
# Release date: 2007-05-04
#
# ###
#
# Name: Striking Sliver
# Colors: R
# Manacost: {R}
# Type: Creature — Sliver
# Text: Sliver creatures you control have first strike. (They deal combat damage before creatures without first strike.)
# Set: Magic 2014 (M14)
# Release date: 2013-07-19
#
# ###
#
# Name: Slivdrazi Monstrosity
# Colors: B, G, R, U, W
# Manacost: {C}{W}{U}{B}{R}{G}
# Type: Legendary Creature — Sliver Eldrazi
# Text: Eldrazi you control are Slivers in addition to their other types.
# Slivers you control have devoid and annihilator 1.
# {3}: Create a 1/1 colorless Eldrazi Sliver creature token. It has "Sacrifice this creature: Add {C}."
# Set: Mystery Booster Playtest Cards 2019 (CMB1)
# Release date: 2019-11-07
#
# ###
#
# Name: Winged Sliver
# Colors: U
# Manacost: {1}{U}
# Type: Creature — Sliver
# Text: All Sliver creatures have flying.
# Set: Tempest (TMP)
# Release date: 1997-10-14
#
# ###
#
# Name: Steelform Sliver
# Colors: W
# Manacost: {2}{W}
# Type: Creature — Sliver
# Text: Sliver creatures you control get +0/+1.
# Set: Magic 2014 (M14)
# Release date: 2013-07-19
#
# ###
#
# Name: Dregscape Sliver
# Colors: B
# Manacost: {1}{B}
# Type: Creature — Sliver
# Text: Each Sliver creature card in your graveyard has unearth {2}.
# Unearth {2} ({2}: Return this card from your graveyard to the battlefield. It gains haste. Exile it at the beginning of the next end step or if it would leave the battlefield. Unearth only as a sorcery.)
# Set: Modern Horizons (MH1)
# Release date: 2019-06-14
#
# ###
#
# Name: Regal Sliver
# Colors: W
# Manacost: {3}{W}
# Type: Creature — Sliver
# Text: Sliver creatures you control have "When this creature enters, Slivers you control get +1/+1 until end of turn if you're the monarch. Otherwise, you become the monarch."
# Set: Commander Masters (CMM)
# Release date: 2023-08-04
#
# ###
#
# Name: Talon Sliver
# Colors: W
# Manacost: {1}{W}
# Type: Creature — Sliver
# Text: All Sliver creatures have first strike.
# Set: Tempest (TMP)
# Release date: 1997-10-14
#
# ###
#
# Name: Crypt Sliver
# Colors: B
# Manacost: {1}{B}
# Type: Creature — Sliver
# Text: All Slivers have "{T}: Regenerate target Sliver."
# Set: Legions (LGN)
# Release date: 2003-02-03
#
# ###
#
# Name: Frenetic Sliver
# Colors: R, U
# Manacost: {1}{U}{R}
# Type: Creature — Sliver
# Text: All Slivers have "{0}: If this permanent is on the battlefield, flip a coin. If you win the flip, exile this permanent and return it to the battlefield under its owner's control at the beginning of the next end step. If you lose the flip, sacrifice it."
# Set: Planar Chaos (PLC)
# Release date: 2007-02-02
#
# ###
#
# Name: Shadow Sliver
# Colors: U
# Manacost: {2}{U}
# Type: Creature — Sliver
# Text: All Sliver creatures have shadow. (They can block or be blocked by only creatures with shadow.)
# Set: Time Spiral (TSP)
# Release date: 2006-10-06
#
# ###
#
# Name: Lazotep Sliver
# Colors: B
# Manacost: {3}{B}
# Type: Creature — Zombie Sliver
# Text: Sliver creatures you control have afflict 2. (Whenever a creature with afflict 2 becomes blocked, defending player loses 2 life.)
# Whenever a nontoken Sliver you control dies, amass Slivers 2. (Put two +1/+1 counters on an Army you control. It's also a Sliver. If you don't control an Army, create a 0/0 black Sliver Army creature token first.)
# Set: Commander Masters (CMM)
# Release date: 2023-08-04
#
# ###
#
# Name: Leeching Sliver
# Colors: B
# Manacost: {1}{B}
# Type: Creature — Sliver
# Text: Whenever a Sliver you control attacks, defending player loses 1 life.
# Set: Magic 2015 (M15)
# Release date: 2014-07-18
#
# ###
#
# Name: The Fifteenth Doctor
# Colors: R, U
# Manacost: {2}{U}{R}
# Type: Legendary Creature — Time Lord Doctor
# Text: Whenever The Fifteenth Doctor enters or attacks, mill three cards. You may put an artifact card with mana value 2 or 3 from among them into your hand.
# The first nonartifact spell you cast each turn has improvise. (Your artifacts can help cast that spell. Each artifact you tap after you're done activating mana abilities pays for {1}.)
# Set: Secret Lair Drop (SLD)
# Release date: 2019-12-02
#
# ###
#
# Name: Manaweft Sliver
# Colors: G
# Manacost: {1}{G}
# Type: Creature — Sliver
# Text: Sliver creatures you control have "{T}: Add one mana of any color."
# Set: Magic 2014 (M14)
# Release date: 2013-07-19
#
#
# ---
#
# Question: It's 2025. What is the name of the last legendary sliver that was printed?
# Answer:

# %%
def answer_question(question, df, max_answer_tokens=150):  
    prompt = create_prompt(question, df)

    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(response)
        return ""

# %%
a1 = answer_question(q1, df)
print("Q: ", q1)
print("A custom: ", a1)
print("===")
print("A basic: ", c1)
# Out:
# Q:  Can you list all creature cards of type Dragon that were printed in 2024?
# A custom:  Chardalyn Dragon, Bonehoard Dracosaur, Dragonhawk, Fate's Tempest, Dragon Trainer, The Powerful Dragon, Hoarding Dragon, Young Blue Dragon // Sand Augury, Astral Dragon, Volcanic Dragon, Brainstealer Dragon, Dragon Mage, Shimmer Dragon, Belltoll Dragon, Fledgling Dragon, and Ambitious Dragonborn were printed in 2024.
# ===
# A basic:
# Question: Can you list all creature cards of type Dragon that were printed in 2024?
# Answer:
# As a AI, I don't have the data regarding future cards. Hence, I cannot provide a list of creature cards of type Dragon that were printed in 2024.

# %%
a2 = answer_question(q2, df)
print("Q: ", q2)
print("A custom: ", a2)
print("===")
print("A basic: ", c2)
# Out:
# Q:  It's 2025. What is the name of the last legendary sliver that was printed?
# A custom:  The last legendary sliver that was printed was The Fifteenth Doctor.
# ===
# A basic:
# Question: It's 2025. What is the name of the last legendary sliver that was printed?
# Answer:
# Unfortunately, as a language model AI, I do not have access to information beyond the current year. I am unable to answer your question. Apologies for the inconvenience.

# %% [markdown]
# # CONCLUSION
#
# Before the context was given, the OpenAI model was incapable for answering, citing limited future information as the reason.
#
# After the context was given, it was able to give an answer.
# Even though the second answer is technically not correct.
# We could probably improve this by:
# - changing the way we build the context documents
# - using few-shot inference in the prompt
# - PEFT retraining of the base model
